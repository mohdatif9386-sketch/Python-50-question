# %%
class Queue:
    def __init__(self):
        self.queue = []
    def is_empty(self):
        return len(self.queue) == 0
    def enqueue(self, value):
        self.queue.append(value)
        print(f"{value} enqueued. Queue {self.queue}")
    def dequeue(self):
        if self.is_empty():
            print("Queue is empty, can not dequeue")
        else:
            removed = self.queue.pop(0)
            print(f"{removed} dequeue. Queue {self.queue}")
    def peek(self):
        if self.is_empty():
            print("queue is empty")
        else:
            print(f"front element : {self.queue[0]}")
q = Queue()

# %%
q.is_empty()
# Out:
# True

# %%
q.enqueue(10)
# Out:
# 10 enqueued. Queue [10]

# %%
q.enqueue(20)
# Out:
# 20 enqueued. Queue [10, 20]

# %%
q.enqueue(30)
# Out:
# 30 enqueued. Queue [10, 20, 30]

# %%
q.peek()
# Out:
# front element : 10

# %%
q.dequeue()
# Out:
# 10 dequeue. Queue [20, 30]

# %%
q.dequeue()
# Out:
# 20 dequeue. Queue [30]

# %%
q.dequeue()
# Out:
# 30 dequeue. Queue []

# %%
q.dequeue()
# Out:
# Queue is empty, can not dequeue
