# %%
def factorial(n):
    if n == 0 or n == 1:
        return n
        print(n)
    return n * factorial(n-1)

# %%
factorial(7)
# Out:
# 5040

# %%
def factorial(number: int) -> int:
    """
     function to calculate the factorial of a number using recursion
    Args:
        (number: int) - A non-negative number
    return:
        int: factorila of a number.
    raises:
        TypeError: if number is not an integer.
        ValueError: if number is negative.
    """
    # validate that input type
    if not isinstance(number, int):
        raise TypeError("Input must be a integer")
    # if input is negative
    if number < 0:
        raise ValueError("Input must be a positive number")\
        
    # logic
    if number == 0 or number == 1:
        return 1
    return number * factorial(number-1)
    
# ---main execution---
if __name__ == "__main__":
    try:
        # Taking input from the user
        user_input = input("Enter Number to calculate the factorial : ")
        # if input is empty
        if not user_input:
            raise TypeError("Input can not be empty")
        # converting inside try block
        try:
            number = int(user_input)
        except ValueError:
            raise TypeError("Input must be an integer")
        # calling the function
        result = factorial(number)
        # print and display the result
        print(f"The factorial of {number} is: {result}")
    except (TypeError, ValueError) as e:
        print(e)
    except Exception as e:
        print(e)
# Out:
# Enter Number to calculate the factorial :  -1
# Input must be a positive number
