# %%
number = 17
for i in range(2, number):
    #print(i)
    if number % i == 0:
        print("not a prime number")
        break
else:
    print("prime number")
# Out:
# prime number

# %%
num = 1000020200093
for i in range(2, int(num ** 0.5) +1):
    if num % i == 0:
        print("not a prime number")
        break
else:
    print("Prime Number")
# Out:
# Prime Number

# %%
def is_prime_number(numbers: int) -> bool:
    """
    function to check whether of number prime or not
    Args
        numbers: int: The number to check.
    return:
        bool: True- If the number is prime and False otherwise.
    raise:
            TypeError: if input is not an integer.
            ValueError: if number is less than 2. (since prime are >= 2).
    """
    # validate that type input an integer
    if not isinstance(numbers, int):
        raise TypeError("input must be an integer")
    # Number should be at least 2 
    if numbers < 2:
        raise ValueError("prime number are greater than or equal to 2")

    for i in range(2, int(number ** 0.5) +1):
        if number % i == 0:
            return False
            break
    else:
        return True

# -- main execution--
if __name__ == "__main__":
    try:
        # taking input from the user
        user_input = input("Enter the number to check is prime or not : ")
        # validate and convert input to integer
        if not user_input.strip().isdigit():
            raise TypeError("input must be a digit (no letter, no string, no float)")
        number = int(user_input)
        # calling the function
        if is_prime_number(number):
            print(f"{number} is a prime number")
        else:
            print(f"{number} is not a prime number")
    except (TypeError, ValueError) as error:
        print(error)
    except Exception as e:
        print(e)
# Out:
# Enter the number to check is prime or not :  89
# 89 is a prime number
