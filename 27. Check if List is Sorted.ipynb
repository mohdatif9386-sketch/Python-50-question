# %%
num_list = [3, 4, 5, 1, 2, 6]
if num_list == sorted(num_list):
    print(True)
else:
    print(False)
# Out:
# False

# %%
number = [1, 2, 3, 4]
for i in range(len(number) - 1):
    if number[i] > number[i+1]:
        print(False)
else:
    print(True)
# Out:
# True

# %%
def is_sorted(number: list) -> bool:
    """
    Check whether a list is sorted in ascending order.

    Args:
        numbers (list): List of numbers

    Returns:
        bool: True if list is sorted, False otherwise

    Raises:
        TypeError: if input is not a list.
        ValueError: if list is empty
    """
    # valithat input type
    if not isinstance(number, list):
        raise TypeError("Input must be a list")
    # empty list check
    if not number:
        raise ValueError("Input cannot be empty")
    #validate element
    for num in number:
        if not isinstance(num, int):
            raise TypeError("Input must be a valid integer in the list")
        
    #logic
    for i in range(len(number) - 1):
        if number[i] > number[i+1]:
            return False
    return True
        
# ---main execution---
if __name__ == "__main__":
    # taking input from the user
    user_input = [1, 2, 3]
    try:
        #calling the function
        if is_sorted(user_input):
            print(True)
        else:
            print(False)
        
    except TypeError as e:
        print("Type Error : ", e)
    except ValueError as e:
        print("Value Error : ", e)
    except Exception as e:
        print("Unexpected Error : ", e)
# Out:
# False
